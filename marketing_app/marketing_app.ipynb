# %% [markdown]
# # Анализ убытков приложения ProcrastinatePRO+

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <dl></dl>
# <div class="toc"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Изучение-данных-и-предобработка" data-toc-modified-id="Изучение-данных-и-предобработка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных и предобработка</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-их-изучение" data-toc-modified-id="Загрузка-данных-и-их-изучение-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных и их изучение</a></span></li><li><span><a href="#Предобработка" data-toc-modified-id="Предобработка-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Используемые-в-ходе-анализа-функции" data-toc-modified-id="Используемые-в-ходе-анализа-функции-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Используемые в ходе анализа функции</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-маркетинговых-показателей" data-toc-modified-id="Анализ-маркетинговых-показателей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ маркетинговых показателей</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Оценка-конверсии-и-удержания-пользователей" data-toc-modified-id="Оценка-конверсии-и-удержания-пользователей-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Оценка конверсии и удержания пользователей</a></span></li></ul></li><li><span><a href="#Анализ-пользователей-из-США" data-toc-modified-id="Анализ-пользователей-из-США-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ пользователей из США</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Приложение `Procrastinate Pro+` предоставило нам лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
# <dl></dl>
#
# <dl>Стоит задача изучить в чем кроется причина маркетинговых убытков, а также, исследовать как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.</dl>
# <dl></dl>

# %% [markdown]
# ## Изучение данных и предобработка

# %% [markdown]
# ### Загрузка данных и их изучение

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import numpy as np

pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
# загрузим базы данных
visits = pd.read_csv('visits_info_short.csv')
orders = pd.read_csv('orders_info_short.csv')
costs = pd.read_csv('costs_info_short.csv')

# универсальная функция для вывода информации о базе данных
def counts(df):
    # информация о датафрейме, количество столбцов и строк, типы данных, названия столбцов и первые 10 строк ДФ.
    print(df.info())
    display(df.head(10))
    print("Количество строк и стобцов: ",df.shape)
    display(df.describe())
    print('Наименование столбцов:')
    display(df.columns)
    # максимальные и минимальные значения
    print('Максимальные значения столбцов:')
    display(df.max())
    print('Минимальные значения столбцов:')
    display(df.min())
    # уникальные значения по возрастанию встречаемости
    print('Значения столбцов по возрастанию встречаемости:')
    for value in df:
        print(df[value].value_counts().sort_values())
    print()
    # проверка на полные дубликаты
    print('Количество повторов:', df.duplicated().sum())
counts(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# ...

# %%
counts(orders)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 5  129100331057  2019-05-01 01:56:28     4.99
# 6  626807144131  2019-05-01 02:39:21     4.99
# 7  914062168985  2019-05-01 02:02:18     4.99
# 8  769669137453  2019-05-01 03:39:47     4.99
# 9  434198630691  2019-05-01 18:16:50     5.99
# Количество строк и стобцов:  (40212, 3)
#                  User Id   Revenue
# ...

# %%
counts(costs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom 113.30
# 1  2019-05-02  FaceBoom  78.10
# 2  2019-05-03  FaceBoom  85.80
# 3  2019-05-04  FaceBoom 136.40
# 4  2019-05-05  FaceBoom 122.10
# 5  2019-05-06  FaceBoom 118.80
# 6  2019-05-07  FaceBoom 101.20
# 7  2019-05-08  FaceBoom 100.10
# 8  2019-05-09  FaceBoom  93.50
# 9  2019-05-10  FaceBoom 104.50
# Количество строк и стобцов:  (1800, 3)
#          costs
# count 1,800.00
# mean     58.61
# std     107.74
# min       0.80
# 25%       6.50
# 50%      12.29
# 75%      33.60
# max     630.00
# Наименование столбцов:
# ...

# %% [markdown]
# ### Предобработка

# %%
# предобработка

# приведем названия столбцов к snakecase
def lower(df):
    df.columns = df.columns.str.replace(' ', '_').str.lower()
lower(visits)   
lower(orders)  
lower(costs)  

#проверка
#visits.info()

# %%
# смена типа данных
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end']  = pd.to_datetime(visits['session_end'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
orders['event_dt'] = pd.to_datetime(orders['event_dt'])


costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# ### Вывод

# %% [markdown]
# Названия столбцов сразу приводим к нижнему регистру для упрощения обращения к ним в ходе анализа.<dl></dl>
# Уникальных значений не много – их легко проверить на скрытые дубликаты, которых нет, поэтому значения столбцов можно не приводить к нижнему регистру, тем более так они будут тяжелее читаться.<dl></dl>
# Пропусков нет, так что дозаполнять данные нет необходимости.<dl></dl>
# Полных повторов, к слову, тоже нет.<dl></dl>
# Необходимо было приведение типов данных ко временному типу данных пандас. В `visits['session_start']` и `visits['session_end']`  нужно сохранить данные до минуты, так как это стартовый и последний момент. (В дальнейшем может понадобиться сортировка от большего к меньшему для определения первого и последнего значения). В `orders['event_dt']` так же важно сохранить точный момент произошедшего события для отслеживания тайминга. В `costs['dt']` время не указано. Рассуждая, что  точность до момента не нужна, ограничимся только приведением к дате.
# <dl></dl>
# Качественные и количественные значения столбцов выглядят правдоподобными, однако стоимость покупки "4.99" $ столбца Revenue(выручка) встречается заметно чаще остальных, возможно она относится к определенному популярному продукту компании.

# %% [markdown]
# ## Используемые в ходе анализа функции

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
  

  )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
     
        # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left'
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
display(profiles.head(5)) # осмотр получившийся таблицы

#задаём горизонт и момент анализа
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа 

# Определим минимальную и максимальную дату привлечения пользователей.
date_max = profiles['dt'].max()
date_min = profiles['dt'].min()
print('Максимальная дата привлечения пользователей:',date_max)
print('Минимальная дата привлечения пользователей:',date_min)
# совпадает с первоначальными данными ДФ counts.

#создаем сводные таблицы и круговые диаграммы распределения пользователей
def pivot_tab(param,count_amount,title,title_p):
# сводная таблица
    pivot_tab = profiles.groupby([param]).agg({count_amount:'nunique'}).sort_values(by=count_amount, ascending = False).rename(columns={count_amount:'total'})
    pivot_tab['total_payer'] = profiles.groupby([param]).agg({'payer':'sum'}).astype('int')
    pivot_tab['percentage_of_payers'] = pivot_tab['total_payer']/pivot_tab['total']*100
    display(pivot_tab)
#круговая диаграмма
    pivot_tab.plot(kind='pie', y = 'total',figsize=(10,10), autopct='%1.1f%%')
    plt.title(title)
    plt.show()
#круговая диаграмма платящих пользователей
    pivot_tab.plot(kind='pie', y = 'total_payer',figsize=(10,10), autopct='%1.1f%%')
    plt.title(title_p)
    plt.show()
    
    
pivot_tab('region','user_id','Круговая диаграмма распределения уникальных пользователй по странам','Круговая диаграмма распределения платящих пользователй по странам')
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True              1.09
# 1  2019-07-09 2019-07-01  False              1.11
# 2  2019-10-01 2019-10-01  False              0.00
# 3  2019-08-22 2019-08-01  False              0.99
# 4  2019-10-02 2019-10-01  False              0.23
# Максимальная дата привлечения пользователей: 2019-10-27
# Минимальная дата привлечения пользователей: 2019-05-01
#                 total  total_payer  percentage_of_payers
# region
# United States  100002         6902                  6.90
# ...

# %%
pivot_tab('channel','user_id','Круговая диаграмма распределения уникальных пользователй по источникам поступления','Круговая диаграмма распределения платящих пользователй по источникам поступления')
# Out:
#                     total  total_payer  percentage_of_payers
# channel
# organic             56439         1160                  2.06
# FaceBoom            29144         3557                 12.20
# TipTop              19561         1878                  9.60
# OppleCreativeMedia   8605          233                  2.71
# LeapBob              8553          262                  3.06
# WahooNetBanner       8553          453                  5.30
# RocketSuperAds       4448          352                  7.91
# MediaTornado         4364          156                  3.57
# YRabbit              4312          165                  3.83
# AdNonSense           3880          440                 11.34
# lambdaMediaAds       2149          225                 10.47

# %%
pivot_tab('device','user_id','Круговая диаграмма распределения уникальных пользователй по используемым девайсам','Круговая диаграмма распределения платящих пользователй по используемым девайсам')
# Out:
#          total  total_payer  percentage_of_payers
# device
# iPhone   54479         3382                  6.21
# Android  35032         2050                  5.85
# PC       30455         1537                  5.05
# Mac      30042         1912                  6.36

# %% [markdown]
# ### Вывод

# %% [markdown]
# <dl></dl>Момент анализа (01.11.2019г.) установлен в соответствии с условиями проведения анализа и подтвердился при предварительном изучении исходных данных: последний пользователей зарегистрировался 31.10 и закончил сессию в ночь на 01.11, далее данные нам не предоставлены поэтому и изучать нечего.
# <dl></dl>
#     Горизонт анализа (14 дней) мы получаем исходя из условий анализа, что окупаемость должна наступать за 2 недели после привлечения пользователей.
#     <dl></dl>
#     Большее количества привлеченных, в том числе платящих пользователей пришло из США. Возможно, там работает большое количество каналов привлечения, либо какой-то один особенно масштабный, также возможно срабатывает органическое привлечение, если магазин англоязычный.
#     <dl></dl>
#     Наибольшее количество уникальных пользователей поступает органическим путем, однако большее количество покупателей приводит не он, а сервис FaceBoom. По конвертации в покупателей органические пользователи стоят только на 3 месте.
#     <dl></dl>
#     IPhone является самым используемым девайсом, хоть он и не сильно ушел в отрыв от остальных перечисленных устройств. Магазину стоит принять во внимание, что лидерами (Iphone, Android) по переходам являются мобильные устройства и быть уверенными, что приложение для них хорошо оптимизировано.

# %% [markdown]
# ## Анализ маркетинговых показателей

# %%
# распределение затрат по каналам
pr = profiles.groupby(['channel']).agg({'acquisition_cost':'sum'}).sort_values(by='acquisition_cost',ascending=False)
pr.loc['TOTAL','acquisition_cost']= pr['acquisition_cost'].sum()  
display(pr)
# всего потрачено
print('Всего потраченно денег на привлечение пользователей:', round(costs['costs'].sum(),2),'долларов.')

# динамика затрат по каналам привлечения
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='sum'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('$')
plt.xlabel('Дата привлечения')
plt.title('Динамика затрат по каналам привлечения')
plt.show()
# Out:
#                     acquisition_cost
# channel
# TipTop                     54,751.30
# FaceBoom                   32,445.60
# WahooNetBanner              5,151.00
# AdNonSense                  3,911.25
# OppleCreativeMedia          2,151.25
# RocketSuperAds              1,833.00
# LeapBob                     1,797.60
# lambdaMediaAds              1,557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00
# TOTAL                     105,497.30
# Всего потраченно денег на привлечение пользователей: 105497.3 долларов.

# %%
# средняя сас потрачено
print('Средняя САС на привлечение пользователей:', round(profiles['acquisition_cost'].mean(),2),'долларов.')

# отфильтруем органических пользователей
profiles = profiles[profiles['channel'] !='organic']
#print(profiles['channel'].unique()) #проверка


# расчитаем среднюю САС.
pr = profiles.groupby(['channel']).agg({'acquisition_cost':'mean'}).sort_values(by='acquisition_cost',ascending=False)
pr.loc['MEAN','acquisition_cost']=profiles['acquisition_cost'].mean()
display(pr)
# средняя сас потрачено
print('Средняя САС на привлечение пользователей без учета органических пользователей:', round(profiles['acquisition_cost'].mean(),2),'долларов.')

# строим график изменений CAC по каналам привлечения во времени
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

profiles.groupby(['channel']).agg({'acquisition_cost':'mean'}).sort_values(by='acquisition_cost',ascending=False).plot(kind='pie', y = 'acquisition_cost',figsize=(10,10), autopct='%1.1f%%')
plt.title("Круговая диаграмма затрат на привлечение")
plt.show()
# Out:
# Средняя САС на привлечение пользователей: 0.7 долларов.
#                     acquisition_cost
# channel
# TipTop                          2.80
# FaceBoom                        1.11
# AdNonSense                      1.01
# lambdaMediaAds                  0.72
# WahooNetBanner                  0.60
# RocketSuperAds                  0.41
# OppleCreativeMedia              0.25
# YRabbit                         0.22
# MediaTornado                    0.22
# LeapBob                         0.21
# MEAN                            1.13
# Средняя САС на привлечение пользователей без учета органических пользователей: 1.13 долларов.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Затраты на привлечение (acquisition_cost) у organic группы равны 0, что полностью оправдано, так как привлечение органических пользователей компания не оплачивала, поэтому данных пользователей можно исключить: маркетинговые траты на привлечения в них не закладываются, а на средний `САС` они влияют. Сервис Tiptop значительно дороже остальных каналов и во времени его цена только растет, далее следуют Faceboom и AdNonSense.
#
# <dl></dl>
# Стоит оценить, насколько затраты на данные каналы окупаются, что мы сделаем далее.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# <dl></dl>
#
# По графикам можно сказать, что ситуация не утешительная. `ROI` далек от самоокупаемости уже с июля 2019 года и только ухудшается, возврата инвестиций нет.
# <dl></dl>
#
# Во времени растет `САС`, что говорит о том, что либо реклама начинает стоить дороже, либо она привлекает меньшее количество пользователей, хотя не исключены обе ситуации.
# <dl></dl>
#
# Хотя `LTV` на 14 день скачет во времени, но на протяжении всего временного промежутка исследования держится в одних значениях (0,7-1,1), что с 07.2019 уже ниже средний `САС` и говорит об несопоставимости расходов на рекламу и доходов от привлеченных пользователей.
# <dl></dl>Полученная информация требует более детального разбора в разбивке по категориям.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <dl></dl>Говоря об стоимости привлечения пользователей стоит сразу отметить, что самыми "дорогими" будут пользователи IPhone (как мы помним они составляют наибольшиий процент от всех устройств) и Mac.
# <dl></dl>При этом при самых низких затратах на привлечение пользователя, лучшая окупаемость инвестиций у PC (за счет неё медленнее опускался общий график в предыдущем разборе!).
# <dl></dl>Возможно маркетологом стоит пересмотреть распределение средств по категориям привлекаемых пользователей по девайсам. PC предстает более выгодным вложением средств на рекламу.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# <dl></dl>По всем графикам США стоит особняком: слишком дорогая стоимость привлечения пользователей (выше в 3 раза остальных стран), при более высокой доходности от пользователей высокая стоимость рекламы не дает никакого возврата инвестиций.
# <dl></dl>Хотя и остальные страны выходят из зоны самоокупаемости вверх, США тянет их обратно вниз на общем графике окупаемости.
# <dl></dl>Нужно разобраться в чем проблема низкого ROI от привлеченных из США пользователей. Одна теория рождается сразу на основании графиков из боле раннего раздела 5: САС США похож на САС канала TipTop с очень высокими затратами на привлечения. Отметим для себя этот факт и вернемся к США позже.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
) 

# сводная таблица по месяцам канала привлечения YRabbit.
print(profiles[profiles['channel'] == 'YRabbit'].groupby(['month']).agg({'acquisition_cost':'sum'}))

# сводная таблица по девайсам по каналу TipTop. 
print(profiles[profiles['channel'] == 'TipTop'].groupby(['device']).agg({'device':'count'}))
# Out:
#             acquisition_cost
# month
# 2019-05-01            299.70
# 2019-06-01            106.20
# 2019-07-01             97.38
# 2019-08-01            124.74
# 2019-09-01            152.79
# 2019-10-01            163.41
#          device
# device
# Android    3889
# Mac        4820
# PC         2012
# iPhone     8840

# %% [markdown]
# LambdaMediaAds показывает неплохие `LTV` и `ROI` (Окупаются инвестиции и по затратам на маркетинг недалеко от средней по каналам).
#
# YRabbit достаточно низко берет за привлеченного пользователя при этом привлекая не самую маленькое сумму доходов компании, поэтому показывает `ROI` лучше, чем остальные каналы. Большой рост `ROI` у YRabbit в июне-июле похож на снижение стоимости за услуги у агентства/канала, так как `LTV` от пользователей не так сильно колебался.
# <dl></dl>Почти все каналы выходят за уровень окупаемости, оутсайдеры – FaceBoom, AdNonSense и уже знакомый нам по предыдущим пунктам исследования, TipTop.
# <dl></dl>Тот доход, что приносят пользователи пришедшие с TipTop далек от вложенных в него средств. По всем показателям видна не окупаемость данного сервиса.
# <dl></dl>Лучшем решением было бы вложить средства в каналы с большей отдачей: LambdaMediaAds, MediaTornado, RocketSuperAds или хотя бы проработать те что находятся ниже точки окупаемости (FaceBoom, AdNonSense, TipTop).

# %% [markdown]
# ### Оценка конверсии и удержания пользователей

# %%
# смотрим конверсию с разбивкой по устройствам
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <dl></dl>Для начала мы убедились, что конверсия верная: она не снижается, растет вверх и стремится к единице.  Лучше всего конвертируются пользователи IPhone и Mac, хуже PC.
# <dl></dl>Конверсия пользователей у всех девайсов нормальная выше 4 %, что достаточно не плохо для приложения, ниже 2 % было бы уже плохо для канала.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <dl></dl>Приятно видеть, что удержание рассчитано верно: оно имеет экспоненциальный характер и платящие пользователи удерживаются лучше не платящих.
# <dl></dl>Однако это единственное, что радует. Пользователи удерживаются плохо. Малое количество неплатящих пользователей остаются до 14 дней (~1%). PC удерживается лучше остальных девайсов, но разница не такая глобальная, чтобы делать акцент на удержании данного девайса.

# %%
# смотрим конверсию с разбивкой по странам
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <dl></dl>Пользователи из США конвертируются лучше, чем из остальных стран, примерно в 2 раза. Остальные страны также находятся на нормальной планке.

# %%
# смотрим удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <dl></dl>Удержание, в особенности в США, опять же тяжело назвать хорошим. Слишком быстро снижается среди платящих пользователей количество возвращающихся пользователей. Не платящие пользователи уходят к своему минимуму уже на 10 день.

# %%
# смотрим конверсию с разбивкой по источникам привлечения
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <dl></dl>Пользователи конвертируются, что хорошо. Где-то показатели выше. В тройке лучших FaceBoom, AdNonSense и показывающий себя хорошо в других частях исследования – LambdaMediaAds.

# %%
# смотрим удержание с разбивкой по источникам привлечения
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <dl></dl>Как и в предыдущих графиках удержания пользователей – показатели удержания не лучшие. Пользователи уходят быстро, не платящие в основном перестают включать приложение уже к 10 дню, стоить сказать, что половина и не возвращается к приложению на 2 день использования.
# <dl></dl>Худшее удержание у FaceBoom и AdNonSense, показавших лучшую конверсию, чем у остальных сервисов. Такое различие в двух показателях может означать, что они предлагают какие-то бонусы или промокоды, установившим приложение для лучшей конвертации в глазах заказчика.

# %% [markdown]
# ## Анализ пользователей из США

# %% [markdown]
# <dl></dl>В п. 6.3. мы отметили для себя, что отгадка в убыточности рекламы кроется в регионе привлеченных пользователей, а именно в США. Поэтому мы рассмотрим его отдельно:

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <dl></dl>Показатели на всех устройства одинаково плохи, немного выделяется Android, но он также не поднимается до уровня самоокупаемости рекламы. Значит проблемы просадки США на общих графиках не в устройствах, а во второй категории для анализа – каналах, ведь что-то общее тянет все устройства вниз.

# %%
# смотрим окупаемость с разбивкой по каналам
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <dl></dl>Целых два убыточных и при этом самых дорогостоящих из рассмотренных нами каналов работают с США: FaceBoom и TipTop. FaceBoom ранее показал практически отсутствующее удержание, а TipTop завышенный ценник за свои услуги. Перераспределение средств от этих каналов могло бы положительно отразиться на выхлоп от маркетинговых издержек. Возможно компания могла бы перенаправить часть денег в YRabbit показывающего лучшую окупаемость инвестиций, либо перераспределить денежные средства на другие регионы, так как рынки тех регионов хуже охвачены, чем рынок США.

# %%
# смотрим конверсию с разбивкой по источникам привлечения
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <dl></dl>Лучше всего изначально конвертируются пользователи в FaceBoom, хотя Tiptop и RocketSuperAds имеют лучшую динамику в лайфтаме. Хуже – более дешёвые каналы MediaTornado и YRabbit. Возможно последние не имеют никакой дополнительной стимуляции пользователей к покупке.

# %%
# смотрим удержание с разбивкой по источникам привлечения
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('region == "United States"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <dl></dl>FaceBoom не удерживает пользователей вовсе, половина платящих пользователей не доживают и до 3 дня. Удержание во всех каналах достаточно стремительно снижается к концу горизонта анализа. Не платящие пользователи практически не доживают к его концу.
# <dl></dl>Разработчикам приложения стоит поднять вопрос о том, как лучше удерживать своих пользователей, так как такая картина наблюдается по всем категориям, независимо от предмета анализа.

# %% [markdown]
# ## Вывод

# %% [markdown]
# <dl>Главное, что стоит принять во внимание – это то что средства вложенные в маркетинг не окупаются. Происходит это по разным причинам:</dl>
#
# 1. Выбор не лучших каналов привлечения пользователей: есть ряд убыточных сервисов, которые не окупаются вовсе. От них стоило бы отказаться и поискать им замены в том же регионе, перераспределить в уже показавшие себя хорошо каналы или же отдать средства на развитие рекламы в другие регионы.
#
# 2. Достаточно низкое удержание пользователей: уже на 2 день пользования не возвращается около половины пользователей. Приложение не цепляет. Возможно оно не соответствует той рекламе и ожиданиям, в которую оно вкладывается, либо оно не достаточно удобно для использования, а может быть проблема кроется где-то в когортной воронке, которую стоило бы рассмотреть отдельно компании.
#
# 3. Пользователи Mac и IPhone стоят дороже остальных, но приносят меньше прибыли и окупаются хуже. Связано это с тем, что привлекают их через дорогие сервисы вроде TipTop. Если компания хочет привлекать пользователей с данными девайсами, то при выборе новых контрагентов стоит отдать предпочтения тем, что приводят владельцев Mac и IPhone. Если же используемые девайсы не так важны, то упор можно делать на общий ROI каналов без разбивки по устройствам.
#
# <dl>Маркетологов стоит обрадовать – на самом деле дела не так плохи, как показалось при первичном анализе. Для начала стоит поработать с 3 убыточными каналами, чтобы минимизировать расходы, а далее можно искать новые сервисы или же улучшать сотрудничество с имеющимися. </dl>
