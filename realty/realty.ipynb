# %% [markdown]
# # Продажа квартир в Санкт-Петербурге

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1><dl></dl>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Изменение типов данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Оценка-сроков-размещения-объявлений" data-toc-modified-id="Оценка-сроков-размещения-объявлений-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Оценка сроков размещения объявлений</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-высота-потолков-в-объявлениях" data-toc-modified-id="Оценка-высота-потолков-в-объявлениях-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Оценка высота потолков в объявлениях</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-количества-комнат-в-квартирах" data-toc-modified-id="Оценка-количества-комнат-в-квартирах-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Оценка количества комнат в квартирах</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-стоимости-квартир" data-toc-modified-id="Оценка-стоимости-квартир-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Оценка стоимости квартир</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-площади-квартир" data-toc-modified-id="Оценка-площади-квартир-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Оценка площади квартир</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-показателей,-влияющих-на-стоимость-квартиры" data-toc-modified-id="Оценка-показателей,-влияющих-на-стоимость-квартиры-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Оценка показателей, влияющих на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Нахождение-городского-диапазона" data-toc-modified-id="Нахождение-городского-диапазона-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Нахождение городского диапазона</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-квартир-в-центре-СПб" data-toc-modified-id="Анализ-квартир-в-центре-СПб-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Анализ квартир в центре СПб</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# Используя данные сервиса Яндекс.Недвижимость определелить типичные предложения на рынке и выявить различия между центром Санкт-Петербурга, его районами и Ленинградской областью.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
dr = pd.read_csv('real_estate_data.csv', sep='\t')
display(dr.info())
display(dr.head(10))
display(dr.shape)

import matplotlib.pyplot as plt 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <dl>Изучены предварительные данные о датафрейме. </dl>
#     <dl>Только 8 столбцов с полными данными, заполнение которых либо происходило автоматически, либо было обяязательным для регистрации объявления на площадки продаж. Остальные столбцы так или иначе страдают от нехватки данных.</dl>
#
# Сразу попадаются на глаза несоответствия по типу данных в столбцах: `first_day_exposition`, `floors_total`, `is_apartment`, `balcony`, `parks_around3000`, `ponds_around3000`, `days_exposition`. Там где предпологаются целые значения – размещены дробные.
#
#  `First_day_exposition` вместо временного типа данных, записано как object.
#
# Название столбца `is_apartment` несет булевую нагрузку, но записано как object. Пропущенные значения в данном столбце скорее всего говорят о том, что данная квартира апартаментами не является, так как такой тип жилья ещё не сильно распространен в Петербурге и в особенности в Ленинградской области. Тоже самое можно сказать про пропуски в столбце `balcony`, но по иной причине: наличие балкона/лоджии является определенным плюсом, повыщающим стоимость жилья, кроме того наличие балкона привлекает больше потенциальных покупателей. Навряд ли риелтор бы забыл о нем упоминуть о объявлениях, так что пропущенные значения можно будет приравнять к 0 в таком столбце.
#     Позже приведем названные столбцы к корректному виду, а пока посмотрим на их уникальные значения.

# %%
#проверка уникальынх значений 
for amount in dr:
    print(dr[amount].value_counts().sort_values())
    print('*********')
# Out:
# 37       1
# 42       1
# 39       1
# 25       1
# 31       2
# 35       2
# 30       2
# 27       2
# 29       3
# 50       3
# 32       4
# 28       4
# 26       5
# 22       8
# 24       8
# 21      12
# 23      16
# 19     603
# 2      640
# 18     642
# 17     650
# 16     761
# 3      769
# 1      872
# 15     948
# 14     986
# 4      986
# 13    1015
# 0     1059
# 12    1225
# 5     1301
# 11    1362
# 6     1482
# 7     1521
# 8     1585
# 20    1694
# 9     1725
# 10    1798
# Name: total_images, dtype: int64
# *********
# 9020000.0       1
# 2235000.0       1
# 6249600.0       1
# 19354948.0      1
# 5827690.0       1
#              ...
# 4200000.0     259
# 4000000.0     260
# 4300000.0     260
# 3500000.0     291
# 4500000.0     342
# Name: last_price, Length: 2978, dtype: int64
# *********
# 76.75       1
# 38.35       1
# 22.40       1
# 275.00      1
# 184.30      1
#          ...
# 44.00     345
# 31.00     346
# 60.00     347
# 42.00     383
# 45.00     419
# ...

# %%
#проверка уникальынх значений 
for amount in dr:
    print(dr[amount].unique())
    print('*********')
# Out:
# [20  7 10  0  2  6  5 18  9  1 16 11  8 12 13  3 15 17 14 19 32  4 35 39
#  23 21 27 30 24 25 28 31 22 29 26 50 42 37]
# *********
# [13000000.  3350000.  5196000. ...  6151120. 21400000. 11475000.]
# *********
# [108.    40.4   56.   ...  66.86 133.81  76.75]
# *********
# ['2019-03-07T00:00:00' '2018-12-04T00:00:00' '2015-08-20T00:00:00' ...
#  '2014-12-29T00:00:00' '2016-09-12T00:00:00' '2015-07-19T00:00:00']
# *********
# [ 3  1  2  4  5  6  0  7 11  8 14 10 15  9 19 16 12]
# *********
# [  2.7     nan   3.03   2.5    2.67   2.56   3.05   2.75   2.6    2.9
#    2.8    2.55   3.     2.65   3.2    2.61   3.25   3.45   2.77   2.85
#    2.64   2.57   4.15   3.5    3.3    2.71   4.     2.47   2.73   2.84
#    3.1    2.34   3.4    3.06   2.72   2.54   2.51   2.78   2.76  25.
#    2.58   3.7    2.52   5.2    2.87   2.66   2.59   2.     2.45   3.6
#    2.92   3.11   3.13   3.8    3.15   3.55   3.16   3.62   3.12   2.53
# ...

# %%
# дубликаты по строкам таблицы
dr.duplicated().sum()
# Out:
# 0

# %% [markdown]
# По уникальным значениям можно сделать определенные выводы о наличии неверно заполненных данных в данном датафрейме:
# 1. Количество комнат никак не может равняться 0, ведь даже студия так или иначе имеет 1 комнату.
# 2. В первых строчках столбца с наименованиями населенных пунктов живут дубликаты по типу посёлок/поселок.
# 3. Подтверждается неверность типа данных в столбцах с количеством балконов, парков, прудов, дней существования объявлений, в дробных частей которых находятся только 0.
# 4. Заметны нетипично высокие здания для Санкт-Петебруга в столбцах с этажами.

# %%
#оценим максимальные и минимальные значения dr
print(dr.max())
print(dr.min())

#изучаем квартиры ниже 500000 рублей.
#display(dr[dr['last_price']<=500000.0])
#изучаем квартиры дороже 500000 рублей.
#display(dr[dr['last_price']>=100000000.0])

#меняем формат на дату и создаем столбцы с указаннами днями, годами, месяцами по нумерации.
dr['first_day_exposition'] = pd.to_datetime(dr['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
dr['weekday'] = dr['first_day_exposition'].dt.weekday
dr['year'] = dr['first_day_exposition'].dt.year
dr['year'] = dr['first_day_exposition'].dt.year
dr['month'] = dr['first_day_exposition'].dt.month
# Out:
# total_images                             50
# last_price                      763000000.0
# total_area                            900.0
# first_day_exposition    2019-05-03T00:00:00
# rooms                                    19
# ceiling_height                        100.0
# floors_total                           60.0
# living_area                           409.7
# floor                                    33
# is_apartment                           True
# studio                                 True
# open_plan                              True
# kitchen_area                          112.0
# balcony                                 5.0
# airports_nearest                    84869.0
# cityCenters_nearest                 65968.0
# parks_around3000                        3.0
# parks_nearest                        3190.0
# ponds_around3000                        3.0
# ponds_nearest                        1344.0
# days_exposition                      1580.0
# dtype: object
# ...

# %% [markdown]
# <dl>Выборка по Maх и Min значениям по цене, как дорогих, так и дешевых квартир выглядят вполне реальными, учитывая удаленность квартир от центра, количество комнат и общей площади. Выбивается только одна квартира стоимостью 12190 рублей. Наверняка риэлтор забыл домножить цифру на 1000 рублей, что мы и сделаем за него далее.</dl>
# <dl>К максимальным и минимальным размерам площади также нет вопросов, они в пределах возможных рыночных предложений. </dl>
# <dl>Максимальное количество этажей стоит проверить, так как Санкт-Петебург и его области не подходят для высокой застройки по грунту, малоэатажки же вполне имеют место быть.</dl>
# <dl>Минимум и максимум высоты потолка также не совпадают с разрешенными по регламентам высотам для застройщиков и требуют отдельного рассмотрения.</dl>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Итак, то что нам удалость подчерпнуть из выборочного обзора данных, так это то, что только 8 столбцов являлись обязательными для заполнения в объявлениях, либо заполнялись системой самостоятельно а именно: `total_images`, `last_price`, `total_area`, `first_day_exposition`, `rooms`, `floor`, `studio`, `open_plan`.
# <dl></dl>
#
# Достаточно мало пропущено значений в `floors_total` и `locality_name`, чтобы можно было не учитывать строки с ними в датафрейме (меньше 1 %). Остальные столбцы предстоит дозаполнять нам.
# <dl></dl>
#
# Количество пустых значений в `parks_around3000` и `ponds_around3000` совпадают, вполне возможно, что указанные критерии отбора были добавлены в один временной промежуток.
#     <dl></dl>
# Имеются столбцы с неверными типами данных.
# Есть неправдоподобные значения в столбцах датафрейма, как слишком маленькие, так и слишком большие, встречаются и просто следствия иных логических выводов, как например, 0 комнат в квартирах.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Начнем обработку с потолков:

# %%
# Стандартные высоты потолков начинаются с 1.64 м и заканчиваются 3.22, остальные значения не являются типовыми для застройщиков, но имеют место быть в частных случаях. 
#display(dr[dr['ceiling_height'] >5]) #по выборке видно, что с 10 м значения высоты потолков становятся уникальными.
# Поэтому отдельно изучим выбросы выше 10 и ниже 2.Возможно высокие здания - частные дома
# высота потолков в 10 метров, может относиться к частным домам, ошибочно указанной высоте дома или просто быть неверным значением. Можно их откинуть выборкой. Выше 24 – опечатка по запятой.
display(dr[dr['ceiling_height'] < 2]) # выборка кавртир с потолками ниже 2 м, выбросы или неверные значения, если потолок ниже 1.6м.
display(dr[dr['ceiling_height'] >10]) # выборка кавртир с потолками больше 10 м, выбросы или неверные значения
display(dr[dr['airports_nearest'] == 34963]) # выброс с 5 балконами и 100 метрами потолка
display(dr[dr['airports_nearest'] == 14814]) # 14 м – это дублированная площадь кухни, неизвестна высота потолка по дому, далее заменем медианой.
display(dr[dr['airports_nearest'] == 36353]) #(10,3 м) расчет среднего потолка для дома 2,8м
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5712              5   1500000.0        42.8           2017-08-14      2
# 16934             5   4100000.0        40.0           2017-10-17      1
# 22590            16   6000000.0        55.0           2018-10-31      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 5712             1.20           2.0         27.5      1          NaN  ...
# 16934            1.75          37.0         17.4      5          NaN  ...
# 22590            1.00          12.0         32.4      7          NaN  ...
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 5712                NaN                  NaN               NaN            NaN
# 16934           18732.0              20444.0               0.0            NaN
# 22590           33053.0              14217.0               2.0          293.0
#
# ...

# %%
# замещение неверных значений
# меняем на приемлимое для частного дома значение. С 24 меняем на точку 2.х, с 10-14 хз чд. 100 похоже на выборос с 5 балконами. 14 похоже на дубликат количества этажей, найти дубли по расстоянию и 10,3 это кухня, так высота потолка 2,8, меньше 2 частные дома – выброс.
# создаём отдельное значение с медианой дома, чтобы она не перезаписывалась при подстановке. 
h36353_mean=dr[(dr['airports_nearest'] == 36353) & dr['ceiling_height'] < 4]['ceiling_height'].mean()
dr['ceiling_height'] =  dr['ceiling_height'].replace(10.30,h36353_mean)
#по той же логике заполним пропуски этого дома
# заполняем пропуски медианой в столбце ceiling_height
dr.loc[19351,'ceiling_height'] = h36353_mean
dr.loc[20142,'ceiling_height'] = h36353_mean

#display(dr.loc[dr.loc[:,'airports_nearest'] == 36353 ]['ceiling_height']) #проверка

# проверка среза с 0 комнат, возможно это студии, либо однокомнатные квартиры, если есть кухня в отдельной площади.
#display(dr[dr['rooms']==0])
#display(dr[dr['rooms']==0].count()) # значения столбца is_studio и kitchen_area подтверждают, что 0 комнат в квартирах студиях.

# заменяем 0 комнат на 1, так как по информации из датафрейма видно, что это студии.
dr['rooms'] = dr['rooms'].replace(0,1)
#заменяем слишком маленькую цену в городе на более вероятную.
dr['last_price'] = dr['last_price'].replace(12190,12190000)

#приводим высоту потолка >20м к нормальному значению.
dr.loc[dr['ceiling_height'] >=20, 'ceiling_height'] = dr.loc[dr['ceiling_height'] >=20, 'ceiling_height'] / 10
display(dr[dr['ceiling_height'] >10]) # в дальнейшем заменить 14 м на среднюю, вместе с Nan Не делю на 10, так как планирую все значения ниже 1,70 откинуть как выбросы, а эту строчку сохраним в ДР.

#найдем границы для отнесения потолков по группам
dr['ceiling_height'].describe()

adv_mean = 2.6979 #значения получены методом describe

adv_std = 0.237247

#разносим высоту потолков по группам
adv_max_ceiling = adv_std*3+adv_mean
adv_min_ceiling = (adv_std*(-3)+adv_mean)

print(f'Высокие потолки начинаются с {adv_max_ceiling}')
print(f'Средние потолки начинаются с {adv_min_ceiling}')

#dr.plot(y='ceiling_height',kind='bar')
dr['ceiling_height'].hist(bins=80,range=(1.9,3.5)) # выборка с 2.4 по 3.5м.
display(dr['ceiling_height'].describe())
#медиана для потолков
median_ceiling_height = dr.loc[dr['ceiling_height']!=14,'ceiling_height'].median()


display(median_ceiling_height)
dr['ceiling_height'].fillna(median_ceiling_height,inplace=True)
dr['ceiling_height'] = dr['ceiling_height'].replace(14,median_ceiling_height)
#проверка замен
#dr['ceiling_height'].isna().sum() #проверка замены всех значений в ceiling_height
#display(dr.loc[355]) #проверка строки

#создаем категории по столбцу ceiling_height, для упрощения ориентирования по высоте потолков
def group_ceiling(height):
    if height >=adv_max_ceiling:
        return 'высокий'
    if adv_max_ceiling>height >=adv_min_ceiling:
        return 'средний'
    if height < adv_min_ceiling:
        return 'низкий'
dr['ceiling_height_group'] = dr['ceiling_height'].apply(group_ceiling)

#создаем категории по столбцу floor, для упрощения ориентирования по этажу
def group_floor(floor,floors): 
    if floor ==floors:
        return 'последний'
    if floors>floor >1:
        return 'другой'
    if floor == 1:
        return 'первый'
# создаем столбец с типом этажа    
dr['floor_group'] = dr.apply(lambda x: group_floor(x['floor'],x['floors_total']),axis=1)

#заполняем пустые значения медианами
#заполняем по группам по количеству комнат столбец жилой площади

for rooms in dr['rooms'].unique():
    median = dr.loc[dr['rooms'] == rooms, 'living_area'].median()
    print(rooms,median)
    dr.loc[(dr['living_area'].isna()) & (dr['rooms']==rooms), 'living_area']= median
print('Пропуски после:', dr['living_area'].isna().sum())

#заполняем по группам по количеству комнат столбец кухонной площади.
for rooms in dr['rooms'].unique():
    median = dr.loc[dr['rooms'] == rooms, 'kitchen_area'].median()
    print(rooms,median)
    dr.loc[(dr['kitchen_area'].isna()) & (dr['rooms']==rooms), 'kitchen_area']= median
print('Пропуски после:', dr['kitchen_area'].isna().sum())

#замена общей медианой пустых значений в parks_around3000 и ponds_around3000.
dr.loc[dr['parks_around3000'].isna(),'parks_around3000'] = dr['parks_around3000'].median()     
dr.loc[dr['ponds_around3000'].isna(),'ponds_around3000'] = dr['ponds_around3000'].median() 
#display(dr['parks_around3000'].isna().sum()) #проверка
#display(dr['ponds_around3000'].isna().sum()) #проверка


#print(dr.head()) #проверка
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 15061            19   5600000.0        56.4           2018-05-11      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 15061            14.0          14.0         32.4      5          NaN  ...
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 15061           14814.0              13610.0               0.0            NaN
#
#       ponds_around3000  ponds_nearest  days_exposition  weekday  year  month
# 15061              0.0            NaN            315.0        4  2018      5
#
# [1 rows x 25 columns]
# Высокие потолки начинаются с 3.409641
# Средние потолки начинаются с 1.9861590000000002
# count    14506.000000
# mean         2.729094
# std          0.313590
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64
# 2.65
# 3 45.0
# ...

# %%
# заполнение пропусков
#пустые значения в is_apartment скорее остались от ручного значения, где вместо False предполчи поставить пропуск.
dr['is_apartment'] = dr['is_apartment'].fillna(False)
#пустые значения в балконах наверняка возникли по тому же принципу, что и в аппартаментах.
dr['balcony'] = dr['balcony'].fillna(0)

# display(dr.info()) проверка отсутствия пропусков

# цикл для приведения к нижнему регистру столбцов из списка list_one
for lower in dr: 
    if 'locality_name' in lower:
        dr[lower] = dr[lower].str.lower()
display(dr['locality_name'].value_counts().sort_values().head()) # проверка 

#приведение locality_name к типу данных object
dr['locality_name'] = dr['locality_name'].astype('str')

from pymystem3 import Mystem
m = Mystem() 
from collections import Counter

# объединим уникальные значения по столбцу locality_name в строку
lemma= " ".join(dr['locality_name'].unique()) 

# лемматизируем уникальные значения и получаемые их словарные формы.
lemma=m.lemmatize(lemma) 

# определим самые частые леммы из столбца locality_name
print(Counter(lemma)) 

#список с леммами для удаления
outsiders = ['платформа', 'при', 'железнодорожной','садовое', 'садоводческое', 'некоммерческое','пансионат','поселок','посёлок','деревня','городского','городское','типа','село','станция','коттеджный','товарищество','станции','городской']

#разделяем строки locality_name_short по словам
dr['locality_name_short'] = dr['locality_name'].str.split(' ')
dr['locality_name_short']= dr['locality_name_short'].replace("ё","е")
# проверка разделения значений столбца 
#display(dr['locality_name_short']) 

#создаем собственную функцию для дальнейшей обработки столбца locality_name_short
def nef(df): 
    p=""
    for i in df:
        if i not in outsiders:
            p+=(" "+i)
    return p 
 
#применяем фунцию nef к столбцу        
dr['locality_name_short'] = dr['locality_name_short'].apply(nef) 
#достаточно малое количество строк с отсуствующим наименованием (0,2 %), можно удалить их.
dr.dropna(subset=['locality_name'],inplace=True)
#print(dr['locality_name'].isna().sum()) # проверка
 

#заполняем по группам по локации столбец расстояния до ближайщего парка.
for locality in dr['locality_name_short'].unique():
    median = dr.loc[dr['locality_name_short'] == locality, 'parks_nearest'].median()
    #print(locality,median)
    dr.loc[(dr['parks_nearest'].isna()) & (dr['locality_name_short']==locality), 'parks_nearest']= median
    dr.loc[(dr['parks_nearest'].isna()), 'parks_nearest']= dr['parks_nearest'].median() 
print('Пропуски после:', dr['parks_nearest'].isna().sum())

#заполняем по группам по локации столбец расстояния до ближайщего водоема.
for locality in dr['locality_name_short'].unique():
    median = dr.loc[dr['locality_name_short'] == locality, 'ponds_nearest'].median()
    #print(locality,median)
    dr.loc[(dr['ponds_nearest'].isna()) & (dr['locality_name_short']==locality), 'ponds_nearest']= median
    dr.loc[(dr['ponds_nearest'].isna()), 'ponds_nearest']= dr['ponds_nearest'].median()   
print('Пропуски после:', dr['ponds_nearest'].isna().sum())

#display(dr['parks_around3000'].isna().sum()) #проверка
#display(dr['ponds_around3000'].isna().sum()) #проверка

#расчитываем цену среднего метра, округляем то рубля, так как копейки в расчетах роли не сыграют.
dr['meter_price'] = round(dr['last_price']/dr['total_area'])

#проверка высокоэтажных домов
display(dr[dr['floors_total']>35].head()) 
#навряд-ли в Кронштадте есть небоскреб, так что заменяем значение на более логичное, в СПБ также самый высокий дом 38 этажей, а не 52 
dr['floors_total'] = dr['floors_total'].replace(60,6)
median_floors = dr.loc[dr['floors_total']!=52,'floors_total'].median()
dr['floors_total'] = dr['floors_total'].replace(52,median_floors)
#отсеим пустые значения dr['floors_total'], так как их малое количество не существенно для проводимого исследования. 
dr =dr.dropna(subset=['floors_total'])
# подсчитываем отношения площадей в отдельных столбцах.
dr['kitchen_cor'] = round(dr['kitchen_area']/dr['total_area'],2)
dr['living_cor'] = round(dr['living_area']/dr['total_area'],2)
display(dr['locality_name_short'].head()) #проверка
dr.head()        #проверка

#для заполнения столбца по количеству дней жизни объявления задаем новый столбец, который определяет пропущена дата или нет.
dr['days_exposition_missing'] = dr['days_exposition'].isna().astype(int)
#суммируем и строим график
dr.groupby('first_day_exposition').agg({'days_exposition_missing':'sum'}).plot()
plt.xlabel('День размещения объявления'), plt.ylabel('Количество объявлений')
plt.title('Распределение объявлений\nбез days_exposition')
plt.show()

# пропущенные значения увеличивались к дате последних объявлений, что говорит о том, что на дату закрытия отчета эти квартиры ещё не были проданы
# заполним разницой последнего опубликованного объявления и датой публикации пропущенных по сроку объявлений Series dr['days_exposition'].
#подсчет пропусков
print('Пропуски до {}'.format(dr['days_exposition'].isna().sum()))
max_dt = dr['first_day_exposition'].max()
#заполняе пропуски разностью first_day_exposition и max_dt в днях
dr.loc[dr['days_exposition'].isna(), 'days_exposition'] = (max_dt - dr.loc[dr['days_exposition'].isna(), 'first_day_exposition']).dt.days
print('Пропуски после {}'.format(dr['days_exposition'].isna().sum()))

#заполняем по группам по локации столбец расстояния до центра города.
for locality in dr['locality_name_short'].unique():
    median = dr.loc[dr['locality_name_short'] == locality, 'cityCenters_nearest'].median()
    #print(locality,median)
    dr.loc[(dr['cityCenters_nearest'].isna()) & (dr['locality_name_short']==locality), 'cityCenters_nearest']= median
    dr.loc[(dr['cityCenters_nearest'].isna()), 'cityCenters_nearest']= dr['cityCenters_nearest'].median() 
print('Пропуски после:', dr['cityCenters_nearest'].isna().sum())

#заполняем по группам по локации столбец расстояния до Пулково.
for locality in dr['locality_name_short'].unique():
    median = dr.loc[dr['locality_name_short'] == locality, 'airports_nearest'].median()
    #print(locality,median)
    dr.loc[(dr['airports_nearest'].isna()) & (dr['locality_name_short']==locality), 'airports_nearest']= median
    dr.loc[(dr['airports_nearest'].isna()), 'airports_nearest']= dr['airports_nearest'].median() 
print('Пропуски после:', dr['airports_nearest'].isna().sum())
# Out:
# посёлок дзержинского     1
# деревня раздолье         1
# деревня нижняя           1
# поселок кирпичное        1
# деревня трубников бор    1
# Name: locality_name, dtype: int64
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# <dl>Для более упрощенного вида датафрейма в таблицу были добавлены новые столбцы:</dl>
#
# 1. Столбец locality_name_short свел количество дубликатов в наименованиях населенных пунктов к минимуму. Так как их названия заносились в ручную, а не выбирались из списка, в столбце появилось много повтряющихся топонимов, но с добавками из "поселков", "станций", "снт", убрав которые мы создали более простой стоблец.
#
# 2. Столбцы weekday, day, month упростили ориентировку по датам объявлений. Создать данные столбцы мы смогли с помощью изменения типа данных в столбце first_day_exposition, который был записан в object.
#
# 3. Сeiling_height_group – сортирует высоту потолка по категориям: низкий, средний и высокий. Логично предположить, что будет некоторая зависимость в цене и покупательской заинтересованности от данного критерия отбора. Значения выше 20 м были поделены на 10, так как они не вписываются в разумные рамки для частных домов и высоких потолков, но идеально объясняются как опечатки. Два значения между 10 и 20 метрами не похожи на опечатку, так как не приводятся, к правдоподобному числу, однако они и далеки от средних значений, поэтому в дальнейшее исследование они входить не будут.
#
# 4. Floor_group – типичный столбец для ориентировки по сайтам с объявлениями о продаже квартир. Однако там он обычно звучит, как "не последний" и "не первый" этаж, возможно нелюбовь к данным этажам мы увидим далее в исследовании.
#
# 5. При заполнении столбцов kitchen_cor и living_cor пришлось стоклнуться с пропусками по площадям кухонь и жилых зон, довольно часто кухни не выдялились отдельно, так как были частью квартир студий и помещений открытого плана, а возможно даже коммуналок, где кухня – общее пространство или кусок с электрической плитой в комнате.
#
# 6. Active_offer является отсылкой к столбцу days_exposition, что говорит что технически объявление было на указанную дату не закрыто.
#
# <dl>Отдельно стиот отметить, что во многих населенных пунктах не достаточно данных по водоемам и паркам, а также по расстояниям до центра города и аэропорта, в некторых они отсутствуют, как таковые. Вполне возможно, что такие пропуски были допущены в отдаленных от города и аэропорта районах Ленинградской области, где заполнение таких критерий только подчернет логистическую удаленность насленного пункта. Парки и водоёмы также могут быть не заполнены по причине их отсутствия в очень маленких поселках Ленинградской области.</dl>
# <dl>Жилых зданий выше 38 этажей не может быть в Санкт-Петебурге, тем более в Кронштадте, находящимся на маленьком острове, судя по последним застройкам – это максимально взятая высота. Значит здание в 60 этажей это опечатка 6 этажного дома.</dl>
# <dl>Малоэтажные дома же могут быть остатками сталинской застройки, а также частынми коттеджами и дачными постройками.</dl>
# <dl>Квартиры с 0 комнат относились к студиям и большим по размеру квартирам со свободной планировкой, что не совсем верно, так как само помещение по сути является комнатой, по этому выводу 0 были заменены на 1 в столбце.</dl>
# <dl></dl>
#
# Пустые значения в `days_exposition` увеличивались к моменту публикации последнего объявления, что говорит о том, что данные объявления были актуальными на момент создания отчета и ещё не закрытыми. Возможно данные квартиры до сих пор не проданы, кто знает...

# %% [markdown]
# ## Изменение типов данных

# %%
#цикл для замены типа даных в столбцах из списка list_name
list_name = ['balcony','floors_total','last_price','ponds_around3000','cityCenters_nearest','parks_around3000','parks_nearest',
            'airports_nearest','parks_around3000','days_exposition','ponds_nearest'] 
for int_amount in dr:
    if int_amount in list_name:
        dr[int_amount] = dr[int_amount].astype('int')
#переименовываем столбец для отражения текущих объявлений
dr.rename(columns = {'days_exposition_missing':'active_offer'},inplace=True)
#булевое значени кажется болле логичным для отображения активных объявлений        
dr['active_offer'] = dr['active_offer'].astype('bool')


display(dr.tail())
display(dr.info())
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 23694            3.70             5         73.3      3         False  ...
# 23695            2.65             5         38.0      4         False  ...
# 23696            2.65             3         29.7      1         False  ...
# 23697            3.00            17         30.5     12         False  ...
# 23698            2.50             5         12.3      1         False  ...
#
#        weekday  year  month  ceiling_height_group floor_group  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# <dl>Заменяем на целые значения дробные.</dl>
# <dl>После всех преобразований часть столбцов можно перевести в целые числа без потерь данных, так как дробная часть там не присутствует(идет 0 после запятой), а пустых значений не осталось.</dl>
# <dl>Количество балконов, этажей, парков и прудов на расстоянии 3000 м, дней жизни объявления – нет сымсла отображать в таблице в вещественых значениях, так как это точные до целого числа значения, измеряющиеся в штуках.</dl>
# <dl>Стоимость квартиры и расстояния тоже приведем к целым значениям, так как точность до копейки или одного сантиметра не повлияет на результаты исследования, а только утяжелит внешний вид предоставляемых вычислений.</dl>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Оценка сроков размещения объявлений

# %%
dr['days_exposition'].plot.box(grid=True)
plt.ylim(1,600)
plt.show()

dr['days_exposition'].hist(bins=50,figsize=(20,5))
plt.xlabel('Количество дней размещения объявления'), plt.ylabel('Количество объявлений')
plt.show()

#расчет IQR
q1_exp = dr['days_exposition'].quantile(0.25)
q3_exp = dr['days_exposition'].quantile(0.75)
iqr_exp = q3_exp - q1_exp 
low_board_exp = q1_exp - (1.5 * iqr_exp)
high_board_exp = q3_exp + (1.5 * iqr_exp)
print(f'Выбросы начинаются с {high_board_exp} дней.')
#display(dr['days_exposition'].describe()) #проверка
#чаще квартиры покупали на 50 дней
print(f'Долгая продажа занимает свыше {q3_exp} дней. Быстрая продажа занимает меньше {q1_exp} дней.')
print('Медиана: ', dr['days_exposition'].quantile(0.50))

#так как iqr задает слишком жесткий отбор для датафрейма (отсеивает 20% объявлений датафрейма), убирем выбросы по значению, соответствующему 0,99 % от выборки.
max_board_exp = dr['days_exposition'].quantile(0.99)
dr = dr[dr['days_exposition']<=max_board_exp]
#display(dr.tail()) #проверка
#display(dr.info()) #проверка
# Out:
# Выбросы начинаются с 528.0 дней.
# Долгая продажа занимает свыше 237.0 дней. Быстрая продажа занимает меньше 43.0 дней.
# Медиана:  94.0

# %% [markdown]
# #### Вывод

# %% [markdown]
# <dl>Нормальный срок продажи распологается между 43 и 237 днями. В среднем квартира продается за 90 дней. Чаще всего же квартиры покупали на 40-50 дней от даты публикации объявления. Такой срок кажется вполне логичным, так как обычно объявления снимаются после продажи, само оформление документов и договора купли-продажи занимает порядка месяца.</dl>

# %% [markdown]
# ### Оценка высота потолков в объявлениях

# %%
dr['ceiling_height'].plot.box(grid=True)
plt.ylim(1,3)
plt.show()

dr['ceiling_height'].hist(bins=20,figsize=(20,5))
plt.xlabel('Высота потолка'), plt.ylabel('Количество объявлений')
plt.show()

#расчет IQR
q1_hei = dr['ceiling_height'].quantile(0.25)
q3_hei = dr['ceiling_height'].quantile(0.75)
iqr_hei = q3_hei - q1_hei 
low_board_height = q1_hei - (1.5 * iqr_hei)
high_board_height = q3_hei + (1.5 * iqr_hei)
print(f'Выбросы начинаются с {high_board_height} метров.' )

#наиболее распространенная высота потолка 2.65м.
#так как iqr задает слишком жесткий отбор для датафрейма (отсеивает ~22% объявлений датафрейма), убирем выбросы по значению, соответствующему 0,99 % от выборки.
max_board_hei = dr['ceiling_height'].quantile(0.995)
min_board_hei = 1-(dr['ceiling_height'].quantile(0.99))
print(f'Наиболее популярные высоты потолков находятся между {q1_hei} и {q3_hei} м.')

dr = dr[(dr['ceiling_height']<=max_board_hei)&(dr['ceiling_height']>=min_board_hei)]

#display(dr.tail()) #проверка
#display(dr.info()) #проверка
# Out:
# Выбросы начинаются с 2.8500000000000005 метров.
# Наиболее популярные высоты потолков находятся между 2.6 и 2.7 м.

# %% [markdown]
# #### Вывод

# %% [markdown]
# <dl>Найденные межквартильным размахом величины слишком жестоко обрезают наши обработанные данные, в основном по верхней границе: убирают из выборки высокие потолки. Есть риск, что отказавшись от категории высоких потолков, мы лишимся большого количества квартир в центре города, так как именно там преобладает старый фонд с большими окнами и огромными потолками. Поэтому ради полноты исследования следаем границы помягче.</dl>
# <dl>По исследованию видно, что в основном в городе и Ленинградской области преобладает типовая застройка с потолками 2.65-2.70 метров. По смещенной вправо гистограмме можно сказать, что застройка тяготеет скорее к высоким потолкам, чем низким.</dl>

# %% [markdown]
# ### Оценка количества комнат в квартирах

# %%
dr['rooms'].plot.box(grid=True)
plt.ylim(1,8)
plt.show()

dr['rooms'].hist(bins=20,figsize=(20,5))
plt.xlabel('Количество комнат'), plt.ylabel('Количество объявлений')
plt.show()

#расчет IQR
q1_rooms = dr['rooms'].quantile(0.25)
q3_rooms = dr['rooms'].quantile(0.75)
iqr_rooms = q3_rooms - q1_rooms 
low_board_rooms = q1_rooms - (1.5 * iqr_rooms)
high_board_rooms = q3_rooms + (1.5 * iqr_rooms)
print(f'Выбросы начинаются с {high_board_rooms} комнат.' )

#чаще продаются однокомнатные квартиры

print(f'Наиболее популярные квартиры с {q1_rooms} до {q3_rooms} комнат.')

dr = dr[(dr['rooms']<=high_board_rooms)]

#display(dr.tail()) #проверка
#display(dr.info()) #проверка
# Out:
# Выбросы начинаются с 6.0 комнат.
# Наиболее популярные квартиры с 1.0 до 3.0 комнат.

# %% [markdown]
# #### Вывод

# %% [markdown]
# <dl>Самые частые предложения на рынке – это пожалуй однокомнатные квартиры, дальше идут двущки и трешки. Жилье с 6 и более комнтатами более редкое и дорогое предложение для опредленной категории покупателей. Такой квартирой пожалуй могут заинтересовться многодетные семьи и более вероятно – состоятельные граждане, любящие простор.</dl>
# <dl>Однушки же популярны для покупки с целью сдачи, для первого собственного жилья, старта семейной жизни, кроме того их легче потому перепродать, поэтому массовость предложений на них легко объясняется.</dl>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, что увеличиваешь сами графики, таким образом их действительно проще изучать.
# </div>

# %% [markdown]
# ### Оценка стоимости квартир

# %%
dr['last_price'].plot.box(grid=True)
plt.ylim(1,14000000)
plt.show()

dr['last_price'].hist(bins=10, figsize=(20,5))
plt.xlabel('Цена за квартиру'), plt.ylabel('Количество объявлений')
plt.show()

dr['last_price'].hist(bins=10, range=(2000000,16000000),figsize=(20,5))
plt.xlabel('Цена за квартиру'), plt.ylabel('Количество объявлений')
plt.show()

#расчет IQR
q1_price = dr['last_price'].quantile(0.25)
q3_price = dr['last_price'].quantile(0.75)
iqr_price = q3_price - q1_price 
low_board_price = q1_price - (1.5 * iqr_price)
high_board_price = q3_price + (1.5 * iqr_price)
print(f'Выбросы начинаются с {high_board_price} рублей.')

max_board_price = dr['last_price'].quantile(0.99)
min_board_price = 1-(dr['last_price'].quantile(0.99))
#боьше всего предложений на квартиры в районе 4000000 рублей.
print(f'Самые часто встречающиеся квартиры ценой между {q1_price} и {q3_price} рублей.')
#граница размаха слишком много откидывает объявлений, поэтому ограничемся отсеиванием 1 % объявлений, для более широкого исследования.
dr = dr[(dr['last_price']<=max_board_price)&(dr['last_price']>=min_board_price)]

#display(dr.tail()) #проверка
#display(dr.info()) #проверка

#проверка идеи, что 4 млн. средняя цена для однокомнатной квартиры 
dr.groupby('rooms').agg({'last_price':'mean'})
# Out:
# Выбросы начинаются с 11525000.0 рублей.
# Самые часто встречающиеся квартиры ценой между 3400000.0 и 6650000.0 рублей.
#          last_price
# rooms
# 1      3.783514e+06
# 2      5.405590e+06
# 3      7.361599e+06
# 4      1.034530e+07
# 5      1.357997e+07
# 6      1.676973e+07

# %% [markdown]
# #### Вывод

# %% [markdown]
# <dl>На момент исследования самые частые и видимо ходовые предложения были на 4 млн. рублей, квартиры ценой до 7 млн также были востребованы. В основном цена в 3.5.-4 млн. рублей установлена на 1-комнтаные квартиры, которые и являются самым частым предложением на рынке.</dl>

# %% [markdown]
# ### Оценка площади квартир

# %%
dr['total_area'].plot.box(grid=True)
plt.ylim(1,160)
plt.show()
#выбросы определены

dr['total_area'].hist(bins=450, range =(0,400), figsize=(20,5))
plt.xlabel('Общая площадь'), plt.ylabel('Количество объявлений')
plt.show()

#расчет IQR
q1_area = dr['total_area'].quantile(0.25)
q3_area = dr['total_area'].quantile(0.75)
iqr_area = q3_area - q1_area 
low_board_area = q1_area - (1.5 * iqr_area)
high_board_area = q3_area + (1.5 * iqr_area)
print(f'Выбросы начинаются с {high_board_area} кв. метров.' )
display(dr['total_area'].describe())#проверка
#чаще всего встречаются 50 метровые квартиры.
print(f'Самые частые метражи квартир между {q1_area} и {q3_area} кв. метров.')

max_board_area = dr['total_area'].quantile(0.99)
min_board_area = 1-(dr['total_area'].quantile(0.99))
dr = dr[(dr['total_area']<=max_board_area)&(dr['total_area']>=min_board_area)]

#display(dr.tail()) #проверка
#display(dr.info()) #проверка

#проверка идеи, что 40-50 м. средняя площадь для однокомнатной квартиры 
dr.groupby('rooms').agg({'total_area':'mean'})
# Out:
# Выбросы начинаются с 110.0 кв. метров.
# count    22946.000000
# mean        57.607458
# std         26.829280
# min         12.000000
# 25%         40.000000
# 50%         51.000000
# 75%         68.000000
# max        460.800000
# Name: total_area, dtype: float64
# Самые частые метражи квартир между 40.0 и 68.0 кв. метров.
#        total_area
# rooms
# 1       37.267845
# 2       55.456334
# 3       75.584995
# 4       95.513598
# 5      119.068870
# 6      130.641935

# %% [markdown]
# #### Вывод

# %% [markdown]
# Как видно из группировки найденный межквартильный интервал относится к 1 и 2-х комнтаным квартирам. Процентов на 10 % поменьше квартир с 3-мя комнатами, далее, чем больше площадь, тем меньше предложений. Однако и людей, которые могут себе позволить такое жилье также сравнительно меньше.

# %% [markdown]
# ### Оценка показателей, влияющих на стоимость квартиры

# %%
#оценка стоимости по количеству комнат в квартире
dr.groupby('rooms').agg({'meter_price':'count'}).plot(kind='pie', y = 'meter_price')
plt.suptitle('Зависимость цены квадратного метра от количества комнат в квартире')
plt.ylabel('Количество комнат в квартире')
plt.show()
#цена за квадратный метр дороже всего у однушек, потом идут двушки и трешки.

dr.boxplot(column = 'meter_price', by = 'floor_group')
plt.ylim(1,200000)
plt.suptitle('Диаграмма размаха по цене за кв. метр')
plt.title('в зависимости от этажа квартиры')
plt.ylabel('Цена за метра квадратный')
plt.xlabel('Этаж')
plt.show()

dr.boxplot(column = 'meter_price', by = 'ceiling_height_group')
plt.ylim(1,200000)
plt.suptitle('Зависимость цены квадратного метра от высоты потолка')
plt.ylabel('Высота потолка')
plt.show()

dr.plot(kind='scatter',x='cityCenters_nearest' ,y='meter_price', grid=True, alpha=0.1)
plt.show()

dr.plot(kind='scatter',x='total_area' ,y='meter_price', grid=True, alpha=0.03)
plt.show()

print('Зависимость цены за квадртаный метра квартиры и удаленности её от центра города:', round(dr['cityCenters_nearest'].corr(dr['meter_price']),2)) #чем дальше тем меньше
print('Зависимость цены за квадртаный метра квартиры и общей площади квартиры:' ,round(dr['total_area'].corr(dr['meter_price']),2))
print('Зависимость цены за квадртаный метра квартиры и этажа квартиры:' ,round(dr['floor'].corr(dr['meter_price']),2)) #чем дальше тем меньше
print('Зависимость цены за квадртаный метра квартиры и количества комнат в квартире:' ,round(dr['rooms'].corr(dr['meter_price']),2))
print('Зависимость цены за квадртаный метра квартиры и высоты потолка:' ,round(dr['ceiling_height'].corr(dr['meter_price']),2))

#оценка по дням недели
#так как границы графика примерно одинаково для 3 столбцов, можно сделать цикл для их формирования
list_day = ['weekday','month','year']
for i in dr:
    if i in list_day:
        dr.boxplot(column = 'meter_price', by = i)
        plt.ylim(20000,175000)
        plt.suptitle('Диаграмма размаха по цене за кв. метр')
        plt.show()

top_ten = dr.groupby('locality_name_short').agg({'meter_price':'count'}) # сделаем сводную таблицу по столбцу locality_name_short и meter_price, выделим общее количество в столбце meter_price квартир по локациям
top_ten['mean'] =  dr.groupby('locality_name_short').agg({'meter_price':'mean'}) # найдем среднюю цену за квадратный метр
top_ten.sort_values(by='meter_price', ascending = False).head(10)
# Out:
# Зависимость цены за квадртаный метра квартиры и удаленности её от центра города: -0.25
# Зависимость цены за квадртаный метра квартиры и общей площади квартиры: 0.14
# Зависимость цены за квадртаный метра квартиры и этажа квартиры: 0.2
# Зависимость цены за квадртаный метра квартиры и количества комнат в квартире: -0.08
# Зависимость цены за квадртаный метра квартиры и высоты потолка: 0.28
#                      meter_price           mean
# locality_name_short
#  санкт-петербург           14858  110346.472338
#  мурино                      585   86083.492308
#  кудрово                     468   95250.882479
#  шушары                      438   78528.760274
#  всеволожск                  391   68526.974425
#  пушкин                      354  102308.316384
#  колпино                     335   75339.426866
#  парголово                   325   90259.716923
#  гатчина                     306   68799.591503
#  выборг                      233   58087.030043

# %% [markdown]
# #### Вывод

# %% [markdown]
# На основании графиков можем сделать пару выводов:
#
# 1. Цена за квадратный метр дороже всего у однушек, потом идут двушки и трешки
#
# 2. Дороже стоит купить квартиру не на первом или последним этаже. Оно и понятно, первый этаж считается проходным и не самым безопасным, последний этаж же разделят с крышей технические коммуникации.
#
# 3. Высокий потолок оценивают дороже, средний меньше, низкий ещё меньше. Прямая зависимость.
#
# 4. Чем дальше квартира находится от центра, тем она дешевле.
#
# 5. 40 метров ценится дороже, чем 100. Хотя правильнее сказать, что цена взаимосвязана с количеством комнат и как следствием площадью.
#
# <dl>Относительно даты публикации объявлений зависимость видна по годам размещения объявлений, чем дальше, тем дороже стоит квадртаный метр квартиры. По дням недели связь не прослеживается.</dl>
#
# Самые плодовитые на публикацию объявлений месяцы: `март`, `апрель`, `сентябрь`.
#
# Корреляционные значения  находятся достаточно близко к 0. По таким показателям можно сказать, что линейная связь слабая либо отсутствует вовсе. Однако бывает, что коэффициент нулевой не потому, что связи между значениями нет, а из-за того, что у неё не линейный характер, который не отражается данным показателем, что мы и увидели по графикам.
#
# Благодаря сводной таблице мы можем увидеть 10 самых открытых на предложения районов. В их числе сам Санкт-Петербург (14858 объявлений), близкие к нему Мурино, Кудрово, Шушары, Всеволожск, более далекий, но более престижный Пушкин.<dl></dl>
#
# По той же таблице делаем вывод, что самая дорогая цена за квадратный метр квартиры в `Санкт-Петебурге` (110347 рублей), а самая низкая – в `Выборге` (58087 рублей).

# %% [markdown]
# ### Нахождение городского диапазона

# %%
dr['center_distance'] = dr['cityCenters_nearest']//1000 #приводим к километрам
report = dr.query('locality_name == "санкт-петербург"').groupby('center_distance').agg({'meter_price':'mean'})        
report['meter_price'].plot(grid = True, figsize = (20,5), legend=None)
plt.axvline(x=7, color ='red',linestyle = ':') #граница конца центра города
plt.axvline(x=13, color ='blue',linestyle = ':') #граница начала Ленинградской области
plt.xticks(report.index.values, report.index.values) #принудительная установка делений на оси x.
plt.ylabel('Цена за метр квадратный')
plt.xlabel('Расстояние от центра Санкт-Петербурга')
plt.show()

# %% [markdown]
# #### Вывод

# %% [markdown]
# <dl>С 7 км начинается спад цены, что я связываю с отдалением от центра города. После 10 км опять же тренд идет на понижение, что уже говорит о границе с более дешевыми квартирами в Ленинградской области.</dl>
# <dl>Провал в цене с 2 до 3 км, я могу свзять с некторыми районами города, где в старом фонде стоят в продаже коммунальные квартиры, жилье там стоит дешевле, да и предложений таких достаточно в центре, взять один район Технологического инстита или Достоевской.</dl>
# <dl>Общий обхват по расстоянию похож на правду, ведь далекий от центра города Курортный район, находится на расстоянии 25-30 км, к которому, например, относится город Сестрорецк. </dl>
# <dl>Скачок в цене на 20 км похож на то, что график достиг престижных пригородов, Петергофа или Пушкина, которые, кстати, являются районами Петербурга, а не частью области.</dl>

# %% [markdown]
# ### Анализ квартир в центре СПб

# %%
#на основании графика выделяем сегмент квартир в центре.
dr_center = dr[dr['center_distance']<=7]

dr['rooms'].hist(bins=20,figsize=(10,5))
dr_center['rooms'].hist(bins=20,figsize=(10,5))
plt.xlabel('Количество комнат'), plt.ylabel('Количество объявлений')
plt.show()

dr['last_price'].hist(bins=10, range=(2000000,16000000),figsize=(10,5))
dr_center['last_price'].hist(bins=10, range=(2000000,16000000),figsize=(10,5))
plt.xlabel('Цена за квартиру'), plt.ylabel('Количество объявлений')
plt.show()

dr['total_area'].hist(bins=450, range =(0,150), figsize=(10,5))
dr_center['total_area'].hist(bins=450, range =(0,150), figsize=(10,5))
plt.xlabel('Общая площадь'), plt.ylabel('Количество объявлений')
plt.show()

dr['ceiling_height'].hist(bins=20, range =(2,4), figsize=(1,5))
dr_center['ceiling_height'].hist(bins=20, range =(2,4), figsize=(10,5))
plt.xlabel('Высота потолка'), plt.ylabel('Количество объявлений')
plt.show()


dr_center.groupby('rooms').agg({'meter_price':'count'}).plot(kind='pie', y = 'meter_price')
plt.suptitle('Зависимость цены квадратного метра от количества комнат в квартире')
plt.ylabel('Количество комнат в квартире')
plt.show()
#цена за квадратный метр дороже всего у двушек, потом идут однушки и трешки.


dr_center.boxplot(column = 'meter_price', by = 'floor_group')
plt.ylim(1,200000)
plt.suptitle('Диаграмма размаха по цене за кв. метр')
plt.title('в зависимости от этажа квартиры')
plt.ylabel('Цена за метра квадратный')
plt.xlabel('Этаж')
plt.show()

dr_center.plot(kind='scatter',x='cityCenters_nearest' ,y='meter_price', grid=True, alpha=0.1)

plt.show()

list_day = ['weekday','month','year']
for i in dr_center:
    if i in list_day:
        dr_center.boxplot(column = 'meter_price', by = i)
        plt.ylim(20000,175000)
        plt.suptitle('Диаграмма размаха по цене за кв. метр')
        plt.show()

#print(dr_center) #проверка

# %% [markdown]
# #### Вывод

# %% [markdown]
# <dl>Отличия, между центром городом и всей областью, которые можно отметить по построенным графикам:</dl>
# <dl>В центре:</dl>
#
# 1.Больше объявлений на 2 и 3 комнатные квартиры в отличие от генеральной совокупности, где сначала преобладают 1 комнатные.
#
# 2.Средняя цена квартиры больше, поэтому чаще встречаются объявления на `6-7 млн. рублей`, а не 3-4.
#
# 3.Площадь квартир практически не отличается от генеральной совокупности, однако объявлений на `60-80` квадратных метров немного больше.
#
# 4.Картина по потолкам вырисовывается похожая, однако высокие потолки, как и предполагалось ранее встречаются чаще.
#
# 5.Двушки и трешки стоят дороже, чем однушки. В генеральной выборке цена относительно них располагалсь в обратном порядке.
#
# 6.Цена по расстоянию от центра распределена практически равномерно, однако виден легкий подъем к увеличению расстояния. Возможно там располагаются более комфортные для проживания районы города.
#
# 7.Самые плодовитые на публикацию объявлений периоды: с `января по май`, с `июля по сентябрь` и `ноябрь`.
#
# 8.А самые плодовитые на публикацию объявлений дни: `понедельник, среда, пятница, суббота, воскресенье`. Наверняка ближе к выходным объявления выкладывают не только риелторы, но и частники, поэтому их количество увеличивается.
#
# <dl>Где нет отличий так это в стоимости квадратного метра за  квартиры на первом и последним этаже: они всё также дешевле иных этажей. А также в повышении стоимости жилья по годам: тенденция общая, как для города с областью, так и для его центра.</dl>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <dl>Часть редких и выбивающихся значений, были убраны в моменте предобработки данных, так как являлись ошибками и опечатками. То что осталось из выбросов, не всегда является аномалией, как например, большое количество комнат или большая высота потолка, но и не типично для среднего значения по выборкам исследования. Я постаралась отразить наиболее полную картину, увиденную мной в полученных данных и сохранить большую их часть для исследования.</dl>
# <dl>К моему удивлению выборка по центру Санкт-Петербурга дала отличные от всего города результаты.</dl>
# <dl>Популярные однушки были сдвинуты с пъедестала двушками. Появилась зависимость между днями публикаций объявлений и их количеством. Квартиры дальше от центра стоят дороже. Больше предложений на большую площадь и на более высокие потолки.</dl>
# <dl>С данными было приятно работать на этой ноте и хочется закончить исследование.</dl>
